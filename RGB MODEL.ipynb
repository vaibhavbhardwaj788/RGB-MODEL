# %%
import skimage.io as io

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
image=io.imread('d4153760-5f91-4d2d-b751-b77902eff4b0.jpg')

# %%
image
# Out:
# array([[[247, 189, 167],
#         [244, 183, 162],
#         [240, 178, 155],
#         ...,
#         [ 10,   0,   0],
#         [ 30,  17,  11],
#         [ 70,  57,  51]],
#
#        [[245, 187, 163],
#         [246, 186, 162],
#         [245, 183, 160],
#         ...,
#         [ 14,   1,   0],
#         [ 19,   6,   0],
#         [ 43,  30,  24]],
#
#        [[255, 195, 169],
#         [255, 196, 170],
#         [255, 193, 168],
#         ...,
#         [ 19,   8,   4],
#         [ 12,   1,   0],
#         [ 16,   5,   1]],
#
#        ...,
#
#        [[231, 227, 215],
#         [234, 230, 218],
#         [234, 230, 218],
#         ...,
#         [214, 211, 202],
#         [213, 210, 201],
#         [212, 209, 200]],
#
#        [[232, 228, 216],
#         [236, 232, 220],
#         [238, 234, 222],
#         ...,
#         [216, 213, 204],
#         [215, 212, 203],
#         [214, 211, 202]],
#
#        [[233, 229, 217],
#         [239, 235, 223],
#         [241, 237, 225],
# ...

# %%
red=image[:,:,0]
blue=image[:,:,1]
green=image[:,:,2]

# %%
plt.imshow(red,cmap='Blues')

# %%
plt.imshow(red,cmap='Greens')

# %%
plt.imshow(red,cmap='Reds')
